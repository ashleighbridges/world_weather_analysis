# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Zip lists and add to list of coordinates
coordinates = list(zip(lats, lngs))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country = citipy.nearest_city(coordinate[0], coordinate[1]).country_code

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc})
                         
  # If an error is experienced, skip the city.
    except:
        
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | auki
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | bayir
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | ous
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | charters towers
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | hilton head island
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | iwaki
# Processing Record 20 of Set 1 | assiniboia
# Processing Record 21 of Set 1 | grindavik
# Processing Record 22 of Set 1 | hofn
# Processing Record 23 of Set 1 | kiama
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | huarmey
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | lethem
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | kharovsk
# Processing Record 33 of Set 1 | khromtau
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | margate
# Processing Record 36 of Set 1 | ballina
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | barra patuca
# Processing Record 39 of Set 1 | bone
# Processing Record 40 of Set 1 | stephenville
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | mount isa
# Processing Record 44 of Set 1 | katsuura
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | suntar
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | bilibino
# Processing Record 50 of Set 1 | baculin
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | ulladulla
# Processing Record 3 of Set 2 | road town
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | mehamn
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | shellbrook
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | campbell river
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | arman
# Processing Record 21 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | lavrentiya
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | nhulunbuy
# Processing Record 26 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 2 | chapais
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | goundam
# Processing Record 30 of Set 2 | karoi
# Processing Record 31 of Set 2 | kailua
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | aitape
# Processing Record 34 of Set 2 | bilma
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | chlorakas
# Processing Record 37 of Set 2 | agirish
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | san policarpo
# Processing Record 42 of Set 2 | wilson
# Processing Record 43 of Set 2 | los llanos de aridane
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | hamina
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | phon
# Processing Record 2 of Set 3 | sterlibashevo
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | pokhara
# Processing Record 5 of Set 3 | tarbes
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | menongue
# Processing Record 8 of Set 3 | asau
# Processing Record 9 of Set 3 | quelimane
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | waddan
# Processing Record 14 of Set 3 | lichinga
# Processing Record 15 of Set 3 | soyo
# Processing Record 16 of Set 3 | bubaque
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | kurchum
# Processing Record 21 of Set 3 | vieira de leiria
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | baykalovo
# Processing Record 24 of Set 3 | maningrida
# Processing Record 25 of Set 3 | basar
# Processing Record 26 of Set 3 | laguna
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | kargopol
# Processing Record 29 of Set 3 | lanzhou
# Processing Record 30 of Set 3 | banda aceh
# Processing Record 31 of Set 3 | aswan
# Processing Record 32 of Set 3 | ugoofaaru
# Processing Record 33 of Set 3 | dodoma
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | bontang
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | aden
# Processing Record 38 of Set 3 | toppenish
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | quartucciu
# Processing Record 41 of Set 3 | constitucion
# Processing Record 42 of Set 3 | vostok
# Processing Record 43 of Set 3 | saint-joseph
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | half moon bay
# Processing Record 47 of Set 3 | praia da vitoria
# Processing Record 48 of Set 3 | nouakchott
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | mareeba
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | olinda
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | ossora
# Processing Record 6 of Set 4 | krishnarajasagara
# Processing Record 7 of Set 4 | birjand
# Processing Record 8 of Set 4 | paamiut
# Processing Record 9 of Set 4 | aklavik
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | achacachi
# Processing Record 13 of Set 4 | san quintin
# Processing Record 14 of Set 4 | butaritari
# Processing Record 15 of Set 4 | boffa
# Processing Record 16 of Set 4 | kamenka
# Processing Record 17 of Set 4 | port-gentil
# Processing Record 18 of Set 4 | ayorou
# Processing Record 19 of Set 4 | nacala
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | abu samrah
# Processing Record 22 of Set 4 | salinopolis
# Processing Record 23 of Set 4 | rudbar
# Processing Record 24 of Set 4 | vagur
# Processing Record 25 of Set 4 | bull savanna
# Processing Record 26 of Set 4 | grand gaube
# Processing Record 27 of Set 4 | baykit
# Processing Record 28 of Set 4 | galle
# Processing Record 29 of Set 4 | bela
# Processing Record 30 of Set 4 | mandalgovi
# Processing Record 31 of Set 4 | muli
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | aras
# Processing Record 34 of Set 4 | jardim
# Processing Record 35 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 4 | saint anthony
# Processing Record 37 of Set 4 | leningradskiy
# Processing Record 38 of Set 4 | luanda
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | te anau
# Processing Record 47 of Set 4 | kathmandu
# Processing Record 48 of Set 4 | merauke
# Processing Record 49 of Set 4 | nanortalik
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | algiers
# Processing Record 2 of Set 5 | chiang rai
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | kimbe
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | sao jose da coroa grande
# Processing Record 8 of Set 5 | razdolnoye
# Processing Record 9 of Set 5 | ambulu
# Processing Record 10 of Set 5 | khatanga
# Processing Record 11 of Set 5 | milkovo
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | krasnoselkup
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | baherden
# Processing Record 16 of Set 5 | axim
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | caraquet
# Processing Record 19 of Set 5 | adelaide
# Processing Record 20 of Set 5 | luganville
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | nsunga
# Processing Record 25 of Set 5 | urengoy
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | burgeo
# Processing Record 28 of Set 5 | iroquois falls
# Processing Record 29 of Set 5 | souillac
# Processing Record 30 of Set 5 | pangai
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | sisimiut
# Processing Record 33 of Set 5 | samana
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | muntilan
# Processing Record 39 of Set 5 | placido de castro
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | pangody
# Processing Record 42 of Set 5 | mayo
# Processing Record 43 of Set 5 | raymond
# Processing Record 44 of Set 5 | pak phanang
# Processing Record 45 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 5 | huejuquilla el alto
# Processing Record 47 of Set 5 | puerto ayora
# Processing Record 48 of Set 5 | biak
# Processing Record 49 of Set 5 | oranjemund
# Processing Record 50 of Set 5 | dubbo
# Processing Record 1 of Set 6 | faanui
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | kutum
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | new norfolk
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | la palma
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | aktas
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | gao
# Processing Record 13 of Set 6 | akdepe
# Processing Record 14 of Set 6 | sitka
# Processing Record 15 of Set 6 | port augusta
# Processing Record 16 of Set 6 | jega
# Processing Record 17 of Set 6 | kloulklubed
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | praia
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | ixtapa
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | salinas
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | olafsvik
# Processing Record 27 of Set 6 | verkhoyansk
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | harper
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | miami
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 6 | alta floresta
# Processing Record 37 of Set 6 | kupang
# Processing Record 38 of Set 6 | lanxi
# Processing Record 39 of Set 6 | villa carlos paz
# Processing Record 40 of Set 6 | nyurba
# Processing Record 41 of Set 6 | leua
# Processing Record 42 of Set 6 | north bend
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | boddam
# Processing Record 45 of Set 6 | champerico
# Processing Record 46 of Set 6 | issoudun
# Processing Record 47 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 6 | matagami
# Processing Record 49 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | broken hill
# Processing Record 1 of Set 7 | dong hoi
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | rio gallegos
# Processing Record 4 of Set 7 | zenzeli
# Processing Record 5 of Set 7 | uray
# Processing Record 6 of Set 7 | nantucket
# Processing Record 7 of Set 7 | rocha
# Processing Record 8 of Set 7 | puerto escondido
# Processing Record 9 of Set 7 | kapoeta
# Processing Record 10 of Set 7 | zavitinsk
# Processing Record 11 of Set 7 | worland
# Processing Record 12 of Set 7 | kletnya
# Processing Record 13 of Set 7 | tura
# Processing Record 14 of Set 7 | semnan
# Processing Record 15 of Set 7 | chiang khong
# Processing Record 16 of Set 7 | shush
# Processing Record 17 of Set 7 | katherine
# Processing Record 18 of Set 7 | itoman
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | iracoubo
# Processing Record 21 of Set 7 | vero beach
# Processing Record 22 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 7 | stanesti
# Processing Record 25 of Set 7 | alekseyevsk
# Processing Record 26 of Set 7 | santa isabel
# Processing Record 27 of Set 7 | morondava
# Processing Record 28 of Set 7 | oktyabrskiy
# Processing Record 29 of Set 7 | gidam
# Processing Record 30 of Set 7 | lock haven
# Processing Record 31 of Set 7 | naron
# Processing Record 32 of Set 7 | lukaya
# Processing Record 33 of Set 7 | staritsa
# Processing Record 34 of Set 7 | muncie
# Processing Record 35 of Set 7 | iralaya
# Processing Record 36 of Set 7 | cleethorpes
# Processing Record 37 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 7 | san carlos del zulia
# Processing Record 39 of Set 7 | vilhena
# Processing Record 40 of Set 7 | dapaong
# Processing Record 41 of Set 7 | tessalit
# Processing Record 42 of Set 7 | saskylakh
# Processing Record 43 of Set 7 | maroantsetra
# Processing Record 44 of Set 7 | khandyga
# Processing Record 45 of Set 7 | oistins
# Processing Record 46 of Set 7 | ruteng
# Processing Record 47 of Set 7 | naze
# Processing Record 48 of Set 7 | port hardy
# Processing Record 49 of Set 7 | yellapur
# Processing Record 50 of Set 7 | otradnoye
# Processing Record 1 of Set 8 | ordubad
# Processing Record 2 of Set 8 | truro
# Processing Record 3 of Set 8 | cap malheureux
# Processing Record 4 of Set 8 | fort nelson
# Processing Record 5 of Set 8 | palana
# Processing Record 6 of Set 8 | cajuru
# Processing Record 7 of Set 8 | taltal
# Processing Record 8 of Set 8 | waingapu
# Processing Record 9 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 8 | agucadoura
# Processing Record 11 of Set 8 | marovoay
# Processing Record 12 of Set 8 | kermen
# Processing Record 13 of Set 8 | ormara
# Processing Record 14 of Set 8 | belyy yar
# Processing Record 15 of Set 8 | leh
# Processing Record 16 of Set 8 | mantua
# Processing Record 17 of Set 8 | gamba
# Processing Record 18 of Set 8 | esmeraldas
# Processing Record 19 of Set 8 | talnakh
# Processing Record 20 of Set 8 | washougal
# Processing Record 21 of Set 8 | sterling
# Processing Record 22 of Set 8 | rockland
# Processing Record 23 of Set 8 | maarianhamina
# Processing Record 24 of Set 8 | santiago
# Processing Record 25 of Set 8 | chara
# Processing Record 26 of Set 8 | qasigiannguit
# Processing Record 27 of Set 8 | bambous virieux
# Processing Record 28 of Set 8 | suchilquitongo
# City not found. Skipping...
# Processing Record 29 of Set 8 | makaha
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | santa vitoria do palmar
# Processing Record 33 of Set 8 | umm lajj
# Processing Record 34 of Set 8 | olga
# Processing Record 35 of Set 8 | iquique
# Processing Record 36 of Set 8 | ayan
# Processing Record 37 of Set 8 | baft
# Processing Record 38 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | shimoda
# Processing Record 41 of Set 8 | chernyshevsk
# Processing Record 42 of Set 8 | dudinka
# Processing Record 43 of Set 8 | denpasar
# Processing Record 44 of Set 8 | buala
# Processing Record 45 of Set 8 | salta
# Processing Record 46 of Set 8 | jinxiang
# Processing Record 47 of Set 8 | carnot
# Processing Record 48 of Set 8 | durres
# Processing Record 49 of Set 8 | urambo
# Processing Record 50 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 9 | livingston
# Processing Record 2 of Set 9 | yumen
# Processing Record 3 of Set 9 | zabol
# Processing Record 4 of Set 9 | lalsot
# Processing Record 5 of Set 9 | tucuman
# Processing Record 6 of Set 9 | kivsharivka
# Processing Record 7 of Set 9 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 9 | mezen
# Processing Record 9 of Set 9 | soe
# Processing Record 10 of Set 9 | nome
# Processing Record 11 of Set 9 | poum
# Processing Record 12 of Set 9 | san clemente
# Processing Record 13 of Set 9 | vazante
# Processing Record 14 of Set 9 | seabra
# Processing Record 15 of Set 9 | kieta
# Processing Record 16 of Set 9 | kununurra
# Processing Record 17 of Set 9 | fort-shevchenko
# Processing Record 18 of Set 9 | marabba
# Processing Record 19 of Set 9 | ivanovka
# Processing Record 20 of Set 9 | kincardine
# Processing Record 21 of Set 9 | qaqortoq
# Processing Record 22 of Set 9 | newport
# Processing Record 23 of Set 9 | zeya
# Processing Record 24 of Set 9 | roald
# Processing Record 25 of Set 9 | yarada
# Processing Record 26 of Set 9 | ambalavao
# Processing Record 27 of Set 9 | date
# Processing Record 28 of Set 9 | batagay
# Processing Record 29 of Set 9 | qui nhon
# Processing Record 30 of Set 9 | yuli
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | nelson bay
# Processing Record 33 of Set 9 | wajir
# Processing Record 34 of Set 9 | gavle
# Processing Record 35 of Set 9 | ushtobe
# Processing Record 36 of Set 9 | batavia
# Processing Record 37 of Set 9 | tutoia
# Processing Record 38 of Set 9 | san jose
# Processing Record 39 of Set 9 | sungaipenuh
# Processing Record 40 of Set 9 | pundaguitan
# Processing Record 41 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 9 | mao
# Processing Record 43 of Set 9 | nongan
# Processing Record 44 of Set 9 | kirkwall
# Processing Record 45 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 9 | tupik
# Processing Record 47 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 48 of Set 9 | richards bay
# Processing Record 49 of Set 9 | la ronge
# Processing Record 50 of Set 9 | fare
# Processing Record 1 of Set 10 | kumla
# Processing Record 2 of Set 10 | vrangel
# Processing Record 3 of Set 10 | oranjestad
# Processing Record 4 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 5 of Set 10 | kidal
# Processing Record 6 of Set 10 | senanga
# Processing Record 7 of Set 10 | xai-xai
# Processing Record 8 of Set 10 | anori
# Processing Record 9 of Set 10 | inhambane
# Processing Record 10 of Set 10 | dicabisagan
# Processing Record 11 of Set 10 | felanitx
# Processing Record 12 of Set 10 | krasne
# Processing Record 13 of Set 10 | dali
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | caconda
# Processing Record 16 of Set 10 | salisbury
# Processing Record 17 of Set 10 | kondinskoye
# Processing Record 18 of Set 10 | minab
# Processing Record 19 of Set 10 | trat
# Processing Record 20 of Set 10 | evensk
# Processing Record 21 of Set 10 | karera
# Processing Record 22 of Set 10 | skjervoy
# Processing Record 23 of Set 10 | darnah
# Processing Record 24 of Set 10 | kargasok
# Processing Record 25 of Set 10 | manokwari
# Processing Record 26 of Set 10 | san francisco
# Processing Record 27 of Set 10 | milove
# Processing Record 28 of Set 10 | cidreira
# Processing Record 29 of Set 10 | bud
# Processing Record 30 of Set 10 | dunedin
# Processing Record 31 of Set 10 | saint-francois
# Processing Record 32 of Set 10 | kahului
# Processing Record 33 of Set 10 | ternovskaya
# Processing Record 34 of Set 10 | winnipeg
# Processing Record 35 of Set 10 | flin flon
# Processing Record 36 of Set 10 | sulphur springs
# Processing Record 37 of Set 10 | laela
# Processing Record 38 of Set 10 | markova
# Processing Record 39 of Set 10 | yerbogachen
# Processing Record 40 of Set 10 | safaga
# Processing Record 41 of Set 10 | doha
# Processing Record 42 of Set 10 | canico
# Processing Record 43 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 10 | igarka
# Processing Record 45 of Set 10 | kashi
# Processing Record 46 of Set 10 | harwich
# Processing Record 47 of Set 10 | brae
# Processing Record 48 of Set 10 | taywarah
# Processing Record 49 of Set 10 | varkaus
# Processing Record 50 of Set 10 | odweyne
# Processing Record 1 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 11 | cacu
# Processing Record 3 of Set 11 | samalkha
# Processing Record 4 of Set 11 | beringovskiy
# Processing Record 5 of Set 11 | burley
# Processing Record 6 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 11 | khorinsk
# Processing Record 8 of Set 11 | hornepayne
# Processing Record 9 of Set 11 | haifa
# Processing Record 10 of Set 11 | madona
# Processing Record 11 of Set 11 | saint-augustin
# Processing Record 12 of Set 11 | rioblanco
# Processing Record 13 of Set 11 | novikovo
# Processing Record 14 of Set 11 | millinocket
# Processing Record 15 of Set 11 | mapiripan
# Processing Record 16 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 11 | posse
# Processing Record 18 of Set 11 | candido mendes
# Processing Record 19 of Set 11 | laizhou
# Processing Record 20 of Set 11 | aykhal
# Processing Record 21 of Set 11 | pokrovsk
# Processing Record 22 of Set 11 | ewo
# Processing Record 23 of Set 11 | flinders
# Processing Record 24 of Set 11 | tommot
# Processing Record 25 of Set 11 | la primavera
# Processing Record 26 of Set 11 | qujing
# Processing Record 27 of Set 11 | mwinilunga
# Processing Record 28 of Set 11 | kaseda
# Processing Record 29 of Set 11 | areosa
# Processing Record 30 of Set 11 | berlevag
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | isangel
# Processing Record 33 of Set 11 | bourail
# Processing Record 34 of Set 11 | maragogi
# Processing Record 35 of Set 11 | ahipara
# Processing Record 36 of Set 11 | anadyr
# Processing Record 37 of Set 11 | isilkul
# Processing Record 38 of Set 11 | mundargi
# Processing Record 39 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 40 of Set 11 | nyazepetrovsk
# Processing Record 41 of Set 11 | ahuimanu
# Processing Record 42 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 43 of Set 11 | massaguet
# Processing Record 44 of Set 11 | ponta delgada
# Processing Record 45 of Set 11 | barcelos
# Processing Record 46 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 11 | greenville
# Processing Record 48 of Set 11 | papara
# Processing Record 49 of Set 11 | san patricio
# Processing Record 50 of Set 11 | bathsheba
# Processing Record 1 of Set 12 | burriana
# Processing Record 2 of Set 12 | marienburg
# Processing Record 3 of Set 12 | coria
# Processing Record 4 of Set 12 | lahij
# Processing Record 5 of Set 12 | tabas
# Processing Record 6 of Set 12 | pokrovskoye
# Processing Record 7 of Set 12 | lydenburg
# Processing Record 8 of Set 12 | lao cai
# Processing Record 9 of Set 12 | visnes
# Processing Record 10 of Set 12 | vanavara
# Processing Record 11 of Set 12 | upington
# Processing Record 12 of Set 12 | sol-iletsk
# Processing Record 13 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 12 | ilulissat
# Processing Record 15 of Set 12 | knysna
# Processing Record 16 of Set 12 | sinegorskiy
# Processing Record 17 of Set 12 | udachnyy
# Processing Record 18 of Set 12 | craig
# Processing Record 19 of Set 12 | zorritos
# Processing Record 20 of Set 12 | sumbe
# Processing Record 21 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 12 | agadez
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | fatehpur
# Processing Record 25 of Set 12 | camacupa
# Processing Record 26 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 12 | mackay
# Processing Record 28 of Set 12 | timmins
# Processing Record 29 of Set 12 | andra
# Processing Record 30 of Set 12 | enshi
# Processing Record 31 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 12 | troitsko-pechorsk
# Processing Record 33 of Set 12 | nemuro
# Processing Record 34 of Set 12 | grand-santi
# Processing Record 35 of Set 12 | yinchuan
# Processing Record 36 of Set 12 | mbamba
# Processing Record 37 of Set 12 | rudiskes
# Processing Record 38 of Set 12 | chak azam sahu
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | warrnambool
# Processing Record 41 of Set 12 | havre-saint-pierre
# Processing Record 42 of Set 12 | luderitz
# Processing Record 43 of Set 12 | lata
# Processing Record 44 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 45 of Set 12 | khani
# Processing Record 46 of Set 12 | catalina foothills
# Processing Record 47 of Set 12 | pochutla
# Processing Record 48 of Set 12 | opuwo
# Processing Record 49 of Set 12 | altamont
# Processing Record 50 of Set 12 | benguela
# Processing Record 1 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 13 | winona
# Processing Record 3 of Set 13 | koungou
# Processing Record 4 of Set 13 | talavera
# Processing Record 5 of Set 13 | bahia de caraquez
# Processing Record 6 of Set 13 | piacabucu
# Processing Record 7 of Set 13 | parras
# City not found. Skipping...
# Processing Record 8 of Set 13 | dodge city
# Processing Record 9 of Set 13 | sao filipe
# Processing Record 10 of Set 13 | waipawa
# Processing Record 11 of Set 13 | mahibadhoo
# Processing Record 12 of Set 13 | vila franca do campo
# Processing Record 13 of Set 13 | belmonte
# Processing Record 14 of Set 13 | vitim
# Processing Record 15 of Set 13 | imbituba
# Processing Record 16 of Set 13 | havelock
# Processing Record 17 of Set 13 | sorrento
# Processing Record 18 of Set 13 | eydhafushi
# Processing Record 19 of Set 13 | zar
# Processing Record 20 of Set 13 | kalaleh
# Processing Record 21 of Set 13 | ust-nera
# Processing Record 22 of Set 13 | voi
# Processing Record 23 of Set 13 | labuhan
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | den helder
# Processing Record 26 of Set 13 | basco
# Processing Record 27 of Set 13 | vidim
# Processing Record 28 of Set 13 | turukhansk
# Processing Record 29 of Set 13 | domoni
# Processing Record 30 of Set 13 | christiana
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 13 | aragats
# Processing Record 33 of Set 13 | labytnangi
# Processing Record 34 of Set 13 | belaya gora
# Processing Record 35 of Set 13 | nadvoitsy
# Processing Record 36 of Set 13 | the valley
# Processing Record 37 of Set 13 | lorengau
# Processing Record 38 of Set 13 | nizwa
# Processing Record 39 of Set 13 | moundsville
# Processing Record 40 of Set 13 | mirina
# City not found. Skipping...
# Processing Record 41 of Set 13 | asyut
# Processing Record 42 of Set 13 | phalodi
# Processing Record 43 of Set 13 | freeport
# Processing Record 44 of Set 13 | san vicente
# Processing Record 45 of Set 13 | solnechnyy
# Processing Record 46 of Set 13 | olginskaya
# Processing Record 47 of Set 13 | porangatu
# Processing Record 48 of Set 13 | beyneu
# Processing Record 49 of Set 13 | salalah
# Processing Record 50 of Set 13 | abeche
# Processing Record 1 of Set 14 | peleduy
# Processing Record 2 of Set 14 | estacion coahuila
# Processing Record 3 of Set 14 | mayumba
# Processing Record 4 of Set 14 | baran
# Processing Record 5 of Set 14 | leninsk-kuznetskiy
# Processing Record 6 of Set 14 | sinegorye
# Processing Record 7 of Set 14 | rock falls
# Processing Record 8 of Set 14 | guerrero negro
# Processing Record 9 of Set 14 | pangnirtung
# Processing Record 10 of Set 14 | guilin
# Processing Record 11 of Set 14 | vorontsovka
# Processing Record 12 of Set 14 | springbok
# Processing Record 13 of Set 14 | bella union
# Processing Record 14 of Set 14 | bima
# Processing Record 15 of Set 14 | sambava
# Processing Record 16 of Set 14 | santa rosa
# Processing Record 17 of Set 14 | bonthe
# Processing Record 18 of Set 14 | zeerust
# Processing Record 19 of Set 14 | paramonga
# Processing Record 20 of Set 14 | hobyo
# Processing Record 21 of Set 14 | abnub
# Processing Record 22 of Set 14 | mitu
# Processing Record 23 of Set 14 | kilakarai
# Processing Record 24 of Set 14 | hami
# Processing Record 25 of Set 14 | warri
# Processing Record 26 of Set 14 | darhan
# Processing Record 27 of Set 14 | keita
# Processing Record 28 of Set 14 | caxito
# Processing Record 29 of Set 14 | deori
# Processing Record 30 of Set 14 | hokitika
# Processing Record 31 of Set 14 | kenai
# Processing Record 32 of Set 14 | atikokan
# Processing Record 33 of Set 14 | walvis bay
# Processing Record 34 of Set 14 | kuragino
# Processing Record 35 of Set 14 | shitanjing
# Processing Record 36 of Set 14 | maunabo
# Processing Record 37 of Set 14 | zigong
# Processing Record 38 of Set 14 | kilindoni
# Processing Record 39 of Set 14 | mitsamiouli
# Processing Record 40 of Set 14 | stockerau
# Processing Record 41 of Set 14 | wolfsburg
# Processing Record 42 of Set 14 | dukat
# Processing Record 43 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 14 | korla
# Processing Record 45 of Set 14 | montes altos
# Processing Record 46 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | badami
# Processing Record 48 of Set 14 | ijuin
# Processing Record 49 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 14 | rongcheng
# Processing Record 1 of Set 15 | gouyave
# Processing Record 2 of Set 15 | skelleftea
# Processing Record 3 of Set 15 | nishihara
# Processing Record 4 of Set 15 | vihti
# Processing Record 5 of Set 15 | iquitos
# Processing Record 6 of Set 15 | kuvshinovo
# Processing Record 7 of Set 15 | shingu
# Processing Record 8 of Set 15 | vanimo
# Processing Record 9 of Set 15 | fershampenuaz
# Processing Record 10 of Set 15 | aasiaat
# Processing Record 11 of Set 15 | risor
# Processing Record 12 of Set 15 | mach
# Processing Record 13 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 15 | mortka
# Processing Record 15 of Set 15 | gasa
# Processing Record 16 of Set 15 | manaure
# Processing Record 17 of Set 15 | berettyoujfalu
# Processing Record 18 of Set 15 | fernie
# Processing Record 19 of Set 15 | port pirie
# Processing Record 20 of Set 15 | zyryanka
# Processing Record 21 of Set 15 | mecca
# Processing Record 22 of Set 15 | karaidel
# Processing Record 23 of Set 15 | camana
# Processing Record 24 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 15 | edd
# Processing Record 26 of Set 15 | nikki
# Processing Record 27 of Set 15 | la union
# Processing Record 28 of Set 15 | kamenskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Reorder the columns
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chokurdakh      RU  70.6333  147.9167     16.34        90         100
# 1         Hermanus      ZA -34.4187   19.2345     57.65        73           0
# 2     Punta Arenas      CL -53.1500  -70.9167     33.91        60          20
# 3             Auki      SB  -8.7676  160.7034     84.15        71          40
# 4         Klaksvik      FO  62.2266   -6.5890     41.92        70          99
# 5            Bayir      TR  37.2687   28.2167     46.92        60           0
# 6            Bluff      NZ -46.6000  168.3333     55.80        67          96
# 7              Ous      RU  60.9058   61.5186     42.66        88         100
# 8          Mataura      NZ -46.1927  168.8643     55.47        64          78
# 9  Charters Towers      AU -20.1000  146.2667     82.36        55          43
#
#    Wind Speed Current Description
# 0        8.25     overcast clouds
# 1        6.87           clear sky
# 2       13.80          few clouds
# 3        3.15    scattered clouds
# 4        4.05     overcast clouds
# 5        3.29           clear sky
# 6        6.53     overcast clouds
# 7        4.52     overcast clouds
# 8        2.86       broken clouds
# 9       11.83    scattered clouds

# %%
# Create CSV file 
weatherpy_db_csv = "WeatherPy_Database.csv"

# Export CSV file
city_data_df.to_csv(weatherpy_db_csv)
